# %%
import pyforest
# importing all necessary libraries

# %%
# importing the dataset
df=pd.read_csv('CARS_1.csv')

# %%
df.head(10)
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
# 5     Toyota Fortuner             99    Diesel                 2755
# 6       Hyundai Creta            731    Diesel                 1493
# 7          Tata Punch            381    Petrol                 1199
# 8     Mahindra Bolero            107    Diesel                 1498
# 9        Maruti Swift            205    Petrol                 1197
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             203 non-null    object
#  1   reviews_count        203 non-null    int64
#  2   fuel_type            203 non-null    object
#  3   engine_displacement  203 non-null    int64
#  4   no_cylinder          203 non-null    int64
#  5   seating_capacity     202 non-null    float64
#  6   transmission_type    203 non-null    object
#  7   fuel_tank_capacity   203 non-null    float64
#  8   body_type            203 non-null    object
#  9   rating               203 non-null    float64
#  10  starting_price       203 non-null    int64
#  11  ending_price         203 non-null    int64
#  12  max_torque_nm        203 non-null    float64
#  13  max_torque_rpm       203 non-null    int64
#  14  max_power_bhp        203 non-null    float64
# ...

# %%
df.describe()
# Out:
#        reviews_count  engine_displacement  no_cylinder  seating_capacity  \
# count     203.000000           203.000000   203.000000        202.000000
# mean      118.684729          2305.921182     4.709360          5.014851
# std       314.331318          1493.837786     2.538664          1.161050
# min         1.000000             0.000000     0.000000          2.000000
# 25%         5.000000          1339.500000     4.000000          5.000000
# 50%        14.000000          1991.000000     4.000000          5.000000
# 75%        83.000000          2996.000000     6.000000          5.000000
# max      2392.000000          6750.000000    12.000000          8.000000
#
#        fuel_tank_capacity      rating  starting_price  ending_price  \
# count          203.000000  203.000000    2.030000e+02  2.030000e+02
# mean            46.143842    4.433498    9.443640e+06  1.112005e+07
# std             28.904207    0.280136    1.357035e+07  1.551746e+07
# ...

# %% [markdown]
# immediately i notice a problem with the engine displacement number of cylinder and fuel tank capacity as they have their min valures as 0.

# %%
df['seating_capacity'].unique()
# Out:
# array([ 5.,  4.,  7.,  8.,  6.,  2., nan])

# %% [markdown]
# from the observation above we can see that there is a null value nan

# %%
df['seating_capacity'].isna().values.any()
# Out:
# True

# %%
mask=df['seating_capacity'].isna()
df[mask]
# Out:
#        car_name  reviews_count fuel_type  engine_displacement  no_cylinder  \
# 143  Mclaren GT              1    Petrol                 3994            8
#
#      seating_capacity transmission_type  fuel_tank_capacity body_type  rating  \
# 143               NaN         Automatic                72.0     Coupe     4.5
#
#      starting_price  ending_price  max_torque_nm  max_torque_rpm  \
# 143        45000000      45000000          630.0               0
#
#      max_power_bhp  max_power_rp
# 143         611.51             0

# %%
df.loc[df['car_name']=='Mclaren GT','seating_capacity'] = 5
df.iloc[143]
# Out:
# car_name               Mclaren GT
# reviews_count                   1
# fuel_type                  Petrol
# engine_displacement          3994
# no_cylinder                     8
# seating_capacity              5.0
# transmission_type       Automatic
# fuel_tank_capacity           72.0
# body_type                   Coupe
# rating                        4.5
# starting_price           45000000
# ending_price             45000000
# max_torque_nm               630.0
# max_torque_rpm                  0
# max_power_bhp              611.51
# max_power_rp                    0
# Name: 143, dtype: object

# %%
df.tail()
# Out:
#                         car_name  reviews_count fuel_type  \
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 198                 1991            4               5.0         Automatic
# 199                 1998            4               5.0         Automatic
# 200                 1956            4               7.0            Manual
# 201                 3998            8               5.0         Automatic
# 202                  796            3               5.0            Manual
#
#      fuel_tank_capacity  body_type  rating  starting_price  ending_price  \
# 198                 0.0  Hatchback     4.5          659000        999000
# ...

# %%
df.columns
# Out:
# Index(['car_name', 'reviews_count', 'fuel_type', 'engine_displacement',
#        'no_cylinder', 'seating_capacity', 'transmission_type',
#        'fuel_tank_capacity', 'body_type', 'rating', 'starting_price',
#        'ending_price', 'max_torque_nm', 'max_torque_rpm', 'max_power_bhp',
#        'max_power_rp'],
#       dtype='object')

# %%
df.shape
# Out:
# (203, 16)

# %%
df.isnull().sum()
# Out:
# car_name               0
# reviews_count          0
# fuel_type              0
# engine_displacement    0
# no_cylinder            0
# seating_capacity       0
# transmission_type      0
# fuel_tank_capacity     0
# body_type              0
# rating                 0
# starting_price         0
# ending_price           0
# max_torque_nm          0
# max_torque_rpm         0
# max_power_bhp          0
# max_power_rp           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 198    False
# 199    False
# 200    False
# 201    False
# 202    False
# Length: 203, dtype: bool

# %%
fhandle=df.groupby('body_type')['starting_price']
fhandle

# %%
mask=df['no_cylinder']==0
df[mask]
# Out:
#                   car_name  reviews_count fuel_type  engine_displacement  \
# 36   Hyundai Kona Electric             40  Electric                    0
# 75                 Kia EV6             15  Electric                    0
# 95                MG ZS EV             14  Electric                    0
# 98                  BMW i4              8  Electric                    0
# 113                 BYD E6              6  Electric                    0
# 117         Mini Cooper SE              3  Electric                    0
# 118            Audi e-tron              7  Electric                    0
# 123         Porsche Taycan              8  Electric                    0
# 127                 BMW iX              3  Electric                    0
# 139      Mercedes-Benz EQS              2  Electric                    0
# 147      Mahindra E Verito             14  Electric                    0
# 158        Strom Motors R3              2  Electric                    0
# ...

# %%
sns.histplot(df['starting_price'], kde=True)
plt.title('Distribution of Price')
plt.xlabel('startng Price')
plt.show()

# %%
datamap=sns.heatmap(df.corr())
plt.show(datamap)

# %%
 df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'Electric'], dtype=object)

# %%
df.loc[df['fuel_type']==10]
# Out:
# Empty DataFrame
# Columns: [car_name, reviews_count, fuel_type, engine_displacement, no_cylinder, seating_capacity, transmission_type, fuel_tank_capacity, body_type, rating, starting_price, ending_price, max_torque_nm, max_torque_rpm, max_power_bhp, max_power_rp]
# Index: []

# %%
df.dropna()
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %%
df.plot(kind='scatter', x='body_type', y='fuel_type')
# Out:
# <AxesSubplot:xlabel='body_type', ylabel='fuel_type'>

# %%
sns.pairplot(df)

# %%
df['starting_price'].plot(kind='hist',  figsize=(12,6), facecolor='grey',edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='body_type', y='starting_price',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='body_type', ylabel='starting_price'>

# %%
df.boxplot('ending_price',figsize=(14,6))
# Out:
# <AxesSubplot:>
